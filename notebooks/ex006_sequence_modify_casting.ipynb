# %% [markdown]
# # Casting and Type Conversion
#
# ## Goal
# Complete each exercise cell, then run the tests.
#
# ## How to work
# - Write your solution(s) in the exercise cell(s)
# - Run `pytest -q`

# %% [markdown]
# ## Exercise 1 — Adding numbers, not strings
#
# **Working code:**
# ```python
# a = "5"
# b = "10"
# print(a + b)
# ```
#
# **Task:** Cast a and b to integers so it prints 15.
#
# **Expected output:**
# ```
# 15
# ```

# %%
# Exercise 1 — YOUR CODE
# Cast a and b to ints so the print shows 15
a = "5"
b = "10"
a = int(a)
b = int(b)
print(a + b)
# Out:
# 15

# %% [markdown]
# ## Exercise 2 — Fixing decimal addition
#
# **Working code:**
# ```python
# price_1 = "2.5"
# price_2 = "3.5"
# print(price_1 + price_2)
# ```
#
# **Task:** Cast to floats so it prints 6.0.
#
# **Expected output:**
# ```
# 6.0
# ```

# %%
# Exercise 2 — YOUR CODE
price_1 = "2.5"
price_2 = "3.5"
price_1 = float(price_1)
price_2 = float(price_2)
print(price_1 + price_2)
# Out:
# 6.0

# %% [markdown]
# ## Exercise 3 — Multiplication mix-up
#
# **Working code:**
# ```python
# days = "7"
# weeks = 4
# print(days * weeks)
# ```
#
# **Task:** Cast days to int so total days is 28.
#
# **Expected output:**
# ```
# 28
# ```

# %%
# Exercise 3 — YOUR CODE
# Cast days to int so the multiplication gives 28
days = "7"
weeks = 4
days = int(days)
print(days * weeks)
# Out:
# 28

# %% [markdown]
# ## Exercise 4 — Joining numbers and text
#
# **Working code:**
# ```python
# score = 500
# print("Your score is", score)
# ```
#
# **Task:** Modify print to use + and cast score to str so it prints "Your score is 500".
#
# **Expected output:**
# ```
# Your score is 500
# ```

# %%
# Exercise 4 — YOUR CODE
score = 500
score = str(score)
print("Your score is " + score)
# Out:
# Your score is 500

# %% [markdown]
# ## Exercise 5 — Losing the decimal
#
# **Working code:**
# ```python
# temperature = 25.9
# print(temperature)
# ```
#
# **Task:** Cast temperature to int so it prints 25.
#
# **Expected output:**
# ```
# 25
# ```

# %%
# Exercise 5 — YOUR CODE
temperature = 25.9
temperature = int(temperature)
print(temperature)
# Out:
# 25

# %% [markdown]
# ## Exercise 6 — Double the input
#
# **Working code:**
# ```python
# num = input()
# print(num + num)
# ```
#
# **Task:** Cast num to int so input 6 prints 12. Show prompt "Enter number:" as in examples with input notation.
#
# **Expected input/output example:**
# ```
# Enter number: [Input: 6]
# 12
# ```

# %%
# Exercise 6 — YOUR CODE
# Print the prompt then read an answer with input()
print("Enter number:")
num = input()
num = int(num)
print(num + num)
# Out:
# Enter number:
# 12

# %% [markdown]
# ## Exercise 7 — Price calculator
#
# **Working code:**
# ```python
# price = input()
# print("Two items cost: " + price + price)
# ```
#
# **Task:** Cast price to float, add it to itself, and print 'Two items cost: 3.0' when input 1.5. Show prompt 'Enter price:' in the example.
#
# **Expected output:**
# ```
# Enter price: [Input: 1.5]
# Two items cost: 3.0
# ```

# %%
# Exercise 7 — YOUR CODE
print("Enter price:")
price = input()
price = float(price)
print("Two items cost: ", price + price)
# Out:
# Enter price:
# Two items cost:  3.0

# %% [markdown]
# ## Exercise 8 — Calculate Area
#
# **Working code:**
# ```python
# width = "10"
# height = "5"
# print("Dimensions: " + width + " by " + height)
# ```
#
# **Task:** Calculate area (width*height) using ints and print 'Area: 50'.
#
# **Expected output:**
# ```
# Area: 50
# ```

# %%
# Exercise 8 — YOUR CODE
width = "10"
height = "5"
width = int(width)
height = int(height)
print("Area:", width*height)
# Out:
# Area: 50

# %% [markdown]
# ## Exercise 9 — Formatting a total
#
# **Working code:**
# ```python
# item = "Burger"
# cost = 5.50
# print("The " + item + " costs £" + cost)
# ```
#
# **Task:** Cast cost to string so it prints 'The Burger costs £5.5'.
#
# **Expected output:**
# ```
# The Burger costs £5.5
# ```

# %%
# Exercise 9 — YOUR CODE
item = "Burger"
cost = 5.50
cost = float(cost)
print("The " + item + " costs £", cost)
# Out:
# The Burger costs £ 5.5

# %% [markdown]
# ## Exercise 10 — The Receipt
#
# **Working code:**
# ```python
# p1 = input()
# p2 = input()
# print("Total: " + p1 + p2)
# ```
#
# **Task:** Cast inputs to floats, sum them, and print 'Total: 30.0' for inputs 10 and 20, showing prompts 'Enter item 1:' and 'Enter item 2:' in the example.
#
# **Expected output example:**
# ```
# Enter item 1: [Input: 10]
# Enter item 2: [Input: 20]
# Total: 30.0
# ```

# %%
# Exercise 10 — YOUR CODE
print("Enter item 1:")
p1 = input()
print("Enter item 2:")
p2 = input()
p1 = float(p1)
p2 = float(p2)
print("Total:", p1 + p2)
# Out:
# Enter item 1:
# Enter item 2:
# Total: 30.0

# %%
# Optional self-check (not graded)
# You can run small experiments here.

# %%
from exercise_runtime_support.student_checker import run_notebook_checks

run_notebook_checks('ex006_sequence_modify_casting')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from exercise_runtime_support.student_checker import run_notebook_checks
# ----> 3 run_notebook_checks('ex006_sequence_modify_casting')
#
# File /workspaces/sequences-make-activities-EdwardPross123/exercise_runtime_support/student_checker/notebook_runtime.py:39, in run_notebook_checks(exercise_key)
#      37 def run_notebook_checks(exercise_key: str) -> None:
#      38     """Execute each tagged exercise cell for the given canonical exercise key."""
# ---> 39     resolved_path = resolve_notebook_path(exercise_key)
#      40     tags = _collect_exercise_tags(resolved_path)
#      41     if not tags:
#
# File /workspaces/sequences-make-activities-EdwardPross123/exercise_runtime_support/notebook_grader.py:38, in resolve_notebook_path(notebook_path, variant)
#      32 def resolve_notebook_path(
#      33     notebook_path: str | Path,
#      34     *,
#      35     variant: Variant | None = None,
#      36 ) -> Path:
#      37     """Resolve an exercise_key string or explicit notebook Path."""
# ---> 38     return resolve_framework_notebook_path(notebook_path, variant=variant)
#
# File /workspaces/sequences-make-activities-EdwardPross123/exercise_runtime_support/exercise_framework/paths.py:162, in resolve_notebook_path(notebook_path, variant)
#     160     if _is_path_like_string(notebook_path):
#     161         _raise_path_like_string_error(notebook_path)
# --> 162     return resolve_exercise_notebook_path(notebook_path, variant=selected_variant)
#     164 if _has_local_metadata_package(repo_root) and _is_source_legacy_notebook_path(
#     165     notebook_path,
#     166     repo_root,
#     167 ):
#     168     _raise_legacy_source_path_error(notebook_path)
#
# File /workspaces/sequences-make-activities-EdwardPross123/exercise_runtime_support/exercise_framework/paths.py:130, in resolve_exercise_notebook_path(exercise_key, variant)
#     124     return _resolve_source_canonical_notebook_path(
#     125         exercise_key,
#     126         variant=selected_variant,
#     127     )
#     129 if not has_local_metadata:
# --> 130     return _resolve_packaged_notebook_path(
#     131         exercise_key,
#     132         variant=selected_variant,
#     133         repo_root=repo_root,
#     134     )
#     136 return _resolve_source_legacy_notebook_path(
#     137     exercise_key,
#     138     variant=selected_variant,
#     139     repo_root=repo_root,
#     140 )
#
# File /workspaces/sequences-make-activities-EdwardPross123/exercise_runtime_support/exercise_framework/paths.py:95, in _resolve_packaged_notebook_path(exercise_key, variant, repo_root)
#      92 if packaged_solution.exists():
#      93     return packaged_solution
# ---> 95 raise FileNotFoundError(
#      96     "Metadata-free packaged repositories do not include solution notebooks "
#      97     "for exercise-key resolution. Expected a solution mirror at "
#      98     f"{packaged_solution} for {exercise_key!r}."
#      99 )
#
# FileNotFoundError: Metadata-free packaged repositories do not include solution notebooks for exercise-key resolution. Expected a solution mirror at /workspaces/sequences-make-activities-EdwardPross123/notebooks/solutions/ex006_sequence_modify_casting.ipynb for 'ex006_sequence_modify_casting'.
